# %%
library(tidyverse)
library(broom) #glance
library(knitr) #kable
library(MASS) #stepAIC
library(data.table) #fread
library(car) #vif

# %% [markdown]
# Recommend a model to predict the y variable -- “Opening Weekend Gross” with the possible predictors (no interactions) -- Runtime, Production Budget, Critic Rating, Audience Rating, and/or Month of Release.
#
# Explain how you determined your model and why you recommended it over other models.

# %%
data6 <- fread('https://raw.githubusercontent.com/wilsonify/AppliedRegression/master/data/wide_release_movies.csv')

# %%
colnames(data6) <- colnames(data6) %>%
                   tolower() %>% 
                   str_replace_all(' ','_') %>% 
                   str_replace_all('[()]','')

# %%
data6 %>% str()
# Out:
# Classes ‘data.table’ and 'data.frame':	680 obs. of  17 variables:
#  $ title                        : chr  "Toy Story 3" "Alice in Wonderland (2010)" "Iron Man 2" "The Twilight Saga: Eclipse" ...
#  $ majorstudio                  : int  1 1 1 0 1 1 1 1 1 1 ...
#  $ runtime                      : int  103 109 125 124 150 148 95 93 98 100 ...
#  $ rating                       : chr  "G" "PG" "PG-13" "PG-13" ...
#  $ production_budget_in_millions: num  200 200 200 68 125 160 69 165 165 260 ...
#  $ in_release                   : int  168 126 104 114 139 175 196 112 119 191 ...
#  $ widest_release               : int  4028 3739 4390 4468 4125 3792 3602 4386 4060 3603 ...
#  $ opening_weekend_gross        : int  110307189 116101023 128122480 64832191 125017372 62785337 56397125 70838207 43732319 48767052 ...
#  $ total_gross                  : int  415004880 334191110 312433331 300531751 295983305 292576195 251513985 238736787 217581231 200821936 ...
#  $ critic_rating                : int  99 51 73 49 78 86 81 58 98 89 ...
#  $ audience_rating              : int  89 55 73 60 84 91 82 54 91 87 ...
#  $ year                         : int  2010 2010 2010 2010 2010 2010 2010 2010 2010 2010 ...
#  $ monthofrelease               : int  6 3 5 6 11 7 7 5 3 11 ...
#  $ logopeningweekendgross       : num  18.5 18.6 18.7 18 18.6 ...
#  $ logproductionbudget          : num  19.1 19.1 19.1 18 18.6 ...
#  $ logwidestrelease             : num  8.3 8.23 8.39 8.4 8.32 ...
#  $ logtotalgross                : num  19.8 19.6 19.6 19.5 19.5 ...
#  - attr(*, ".internal.selfref")=<externalptr>

# %%
subdata6 <- data6[,c('opening_weekend_gross','runtime','production_budget_in_millions','critic_rating','audience_rating','monthofrelease')]

# %%
subdata6 <- subdata6 %>% drop_na()

# %%
subdata6 %>% str()
# Out:
# Classes ‘data.table’ and 'data.frame':	642 obs. of  6 variables:
#  $ opening_weekend_gross        : int  110307189 116101023 128122480 64832191 125017372 62785337 56397125 70838207 43732319 48767052 ...
#  $ runtime                      : int  103 109 125 124 150 148 95 93 98 100 ...
#  $ production_budget_in_millions: num  200 200 200 68 125 160 69 165 165 260 ...
#  $ critic_rating                : int  99 51 73 49 78 86 81 58 98 89 ...
#  $ audience_rating              : int  89 55 73 60 84 91 82 54 91 87 ...
#  $ monthofrelease               : int  6 3 5 6 11 7 7 5 3 11 ...
#  - attr(*, ".internal.selfref")=<externalptr>

# %%
full_fit <- lm(formula = opening_weekend_gross~
          runtime+
          production_budget_in_millions+
          critic_rating+
          audience_rating+
          monthofrelease
          ,data = subdata6)

# %%
summary(full_fit)
# Out:
# Call:
# lm(formula = opening_weekend_gross ~ runtime + production_budget_in_millions +
#     critic_rating + audience_rating + monthofrelease, data = subdata6)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -56227789  -8131880  -2314642   4932399 122214813
#
# Coefficients:
#                                Estimate Std. Error t value Pr(>|t|)
# (Intercept)                   -18230699    5289930  -3.446 0.000606 ***
# runtime                           91574      52339   1.750 0.080661 .
# production_budget_in_millions    311234      14715  21.150  < 2e-16 ***
# critic_rating                     -9768      36260  -0.269 0.787714
# audience_rating                  280290      60774   4.612 4.82e-06 ***
# monthofrelease                  -525647     215011  -2.445 0.014766 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 17990000 on 636 degrees of freedom
# Multiple R-squared:  0.5176,	Adjusted R-squared:  0.5139
# F-statistic: 136.5 on 5 and 636 DF,  p-value: < 2.2e-16

# %%
models <- interaction( c('runtime','production_budget_in_millions','critic_rating','audience_rating','monthofrelease')
                      ,c('runtime','production_budget_in_millions','critic_rating','audience_rating','monthofrelease')
                      ,c('runtime','production_budget_in_millions','critic_rating','audience_rating','monthofrelease')
                      ,c('runtime','production_budget_in_millions','critic_rating','audience_rating','monthofrelease')
                      ,c('runtime','production_budget_in_millions','critic_rating','audience_rating','monthofrelease')
                      ,c('runtime','production_budget_in_millions','critic_rating','audience_rating','monthofrelease')
                      , sep='+') %>% 
           levels() %>% 
           paste("opening_weekend_gross ~",.)

# %%
scaled <- scale(subdata6) %>% as.data.frame()

# %%
scaled %>% cor() %>% round(2)
# Out:
#                               opening_weekend_gross runtime
# opening_weekend_gross          1.0000               0.3742
# runtime                        0.3742               1.0000
# production_budget_in_millions  0.6926               0.4128
# critic_rating                  0.1538               0.1910
# audience_rating                0.2991               0.3438
# monthofrelease                -0.0175               0.0754
#                               production_budget_in_millions critic_rating
# opening_weekend_gross         0.6926                        0.1538
# runtime                       0.4128                        0.1910
# production_budget_in_millions 1.0000                        0.0691
# critic_rating                 0.0691                        1.0000
# audience_rating               0.1814                        0.6612
# monthofrelease                0.0442                        0.1274
#                               audience_rating monthofrelease
# opening_weekend_gross         0.2991          -0.0175
# runtime                       0.3438           0.0754
# production_budget_in_millions 0.1814           0.0442
# critic_rating                 0.6612           0.1274
# audience_rating               1.0000           0.1082
# monthofrelease                0.1082           1.0000

# %%
AICc_from_AIC <- function(AIC,fit) {    
    n <- length(fit$residuals)  
    k <- length(fit$coefficients) - 1    
    correction <- (2*k^2 + 2*k) / (n - k - 1)
    return ( AIC + correction )
    }
    
result <- data_frame()
for (form in models) {
    #print(form)
    fit <- lm(data=scaled, formula = as.formula(form))        
    glance_of_fit <- glance(fit) %>%
                     mutate( model=form
                            ,k = length(fit$coefficients) - 1   
                            ,AICc = AICc_from_AIC(AIC,fit)) %>% 
                     dplyr::select(c( 'model' 
                                     ,'k'
                                     ,'adj.r.squared'
                                     ,'AIC'
                                     ,'AICc'
                                     ,'BIC')
                                  )
    result <- rbind(result,glance_of_fit)
}

# %%
result
# Out:
#       model
# 1     opening_weekend_gross ~ audience_rating+audience_rating+audience_rating+audience_rating+audience_rating+audience_rating
# 2     opening_weekend_gross ~ critic_rating+audience_rating+audience_rating+audience_rating+audience_rating+audience_rating
# 3     opening_weekend_gross ~ monthofrelease+audience_rating+audience_rating+audience_rating+audience_rating+audience_rating
# 4     opening_weekend_gross ~ production_budget_in_millions+audience_rating+audience_rating+audience_rating+audience_rating+audience_rating
# 5     opening_weekend_gross ~ runtime+audience_rating+audience_rating+audience_rating+audience_rating+audience_rating
# 6     opening_weekend_gross ~ audience_rating+critic_rating+audience_rating+audience_rating+audience_rating+audience_rating
# 7     opening_weekend_gross ~ critic_rating+critic_rating+audience_rating+audience_rating+audience_rating+audience_rating
# 8     opening_weekend_gross ~ monthofrelease+critic_rating+audience_rating+audience_rating+audience_rating+audience_rating
# 9     opening_weekend_gross ~ production_budget_in_millions+critic_rating+audience_rating+audience_rating+audience_rating+audience_rating
# 10    opening_weekend_gross ~ runtime+critic_rating+audience_rating+audience_rating+audience_rating+audience_rating
# 11    opening_weekend_gross ~ audience_rating+monthofrelease+audience_rating+audience_rating+audience_rating+audience_rating
# 12    opening_weekend_gross ~ critic_rating+monthofrelease+audience_rating+audience_rating+audience_rating+audience_rating
# 13    opening_weekend_gross ~ monthofrelease+monthofrelease+audience_rating+audience_rating+audience_rating+audience_rating
# 14    opening_weekend_gross ~ production_budget_in_millions+monthofrelease+audience_rating+audience_rating+audience_rating+audience_rating
# 15    opening_weekend_gross ~ runtime+monthofrelease+audience_rating+audience_rating+audience_rating+audience_rating
# 16    opening_weekend_gross ~ audience_rating+production_budget_in_millions+audience_rating+audience_rating+audience_rating+audience_rating
# 17    opening_weekend_gross ~ critic_rating+production_budget_in_millions+audience_rating+audience_rating+audience_rating+audience_rating
# 18    opening_weekend_gross ~ monthofrelease+production_budget_in_millions+audience_rating+audience_rating+audience_rating+audience_rating
# 19    opening_weekend_gross ~ production_budget_in_millions+production_budget_in_millions+audience_rating+audience_rating+audience_rating+audience_rating
# 20    opening_weekend_gross ~ runtime+production_budget_in_millions+audience_rating+audience_rating+audience_rating+audience_rating
# 21    opening_weekend_gross ~ audience_rating+runtime+audience_rating+audience_rating+audience_rating+audience_rating
# 22    opening_weekend_gross ~ critic_rating+runtime+audience_rating+audience_rating+audience_rating+audience_rating
# 23    opening_weekend_gross ~ monthofrelease+runtime+audience_rating+audience_rating+audience_rating+audience_rating
# 24    opening_weekend_gross ~ production_budget_in_millions+runtime+audience_rating+audience_rating+audience_rating+audience_rating
# 25    opening_weekend_gross ~ runtime+runtime+audience_rating+audience_rating+audience_rating+audience_rating
# 26    opening_weekend_gross ~ audience_rating+audience_rating+critic_rating+audience_rating+audience_rating+audience_rating
# 27    opening_weekend_gross ~ critic_rating+audience_rating+critic_rating+audience_rating+audience_rating+audience_rating
# 28    opening_weekend_gross ~ monthofrelease+audience_rating+critic_rating+audience_rating+audience_rating+audience_rating
# 29    opening_weekend_gross ~ production_budget_in_millions+audience_rating+critic_rating+audience_rating+audience_rating+audience_rating
# 30    opening_weekend_gross ~ runtime+audience_rating+critic_rating+audience_rating+audience_rating+audience_rating
# ⋮     ⋮
# 15596 opening_weekend_gross ~ audience_rating+runtime+production_budget_in_millions+runtime+runtime+runtime
# 15597 opening_weekend_gross ~ critic_rating+runtime+production_budget_in_millions+runtime+runtime+runtime
# 15598 opening_weekend_gross ~ monthofrelease+runtime+production_budget_in_millions+runtime+runtime+runtime
# 15599 opening_weekend_gross ~ production_budget_in_millions+runtime+production_budget_in_millions+runtime+runtime+runtime
# 15600 opening_weekend_gross ~ runtime+runtime+production_budget_in_millions+runtime+runtime+runtime
# 15601 opening_weekend_gross ~ audience_rating+audience_rating+runtime+runtime+runtime+runtime
# 15602 opening_weekend_gross ~ critic_rating+audience_rating+runtime+runtime+runtime+runtime
# 15603 opening_weekend_gross ~ monthofrelease+audience_rating+runtime+runtime+runtime+runtime
# 15604 opening_weekend_gross ~ production_budget_in_millions+audience_rating+runtime+runtime+runtime+runtime
# 15605 opening_weekend_gross ~ runtime+audience_rating+runtime+runtime+runtime+runtime
# 15606 opening_weekend_gross ~ audience_rating+critic_rating+runtime+runtime+runtime+runtime
# 15607 opening_weekend_gross ~ critic_rating+critic_rating+runtime+runtime+runtime+runtime
# 15608 opening_weekend_gross ~ monthofrelease+critic_rating+runtime+runtime+runtime+runtime
# 15609 opening_weekend_gross ~ production_budget_in_millions+critic_rating+runtime+runtime+runtime+runtime
# 15610 opening_weekend_gross ~ runtime+critic_rating+runtime+runtime+runtime+runtime
# 15611 opening_weekend_gross ~ audience_rating+monthofrelease+runtime+runtime+runtime+runtime
# 15612 opening_weekend_gross ~ critic_rating+monthofrelease+runtime+runtime+runtime+runtime
# 15613 opening_weekend_gross ~ monthofrelease+monthofrelease+runtime+runtime+runtime+runtime
# 15614 opening_weekend_gross ~ production_budget_in_millions+monthofrelease+runtime+runtime+runtime+runtime
# 15615 opening_weekend_gross ~ runtime+monthofrelease+runtime+runtime+runtime+runtime
# 15616 opening_weekend_gross ~ audience_rating+production_budget_in_millions+runtime+runtime+runtime+runtime
# 15617 opening_weekend_gross ~ critic_rating+production_budget_in_millions+runtime+runtime+runtime+runtime
# 15618 opening_weekend_gross ~ monthofrelease+production_budget_in_millions+runtime+runtime+runtime+runtime
# 15619 opening_weekend_gross ~ production_budget_in_millions+production_budget_in_millions+runtime+runtime+runtime+runtime
# 15620 opening_weekend_gross ~ runtime+production_budget_in_millions+runtime+runtime+runtime+runtime
# 15621 opening_weekend_gross ~ audience_rating+runtime+runtime+runtime+runtime+runtime
# 15622 opening_weekend_gross ~ critic_rating+runtime+runtime+runtime+runtime+runtime
# 15623 opening_weekend_gross ~ monthofrelease+runtime+runtime+runtime+runtime+runtime
# 15624 opening_weekend_gross ~ production_budget_in_millions+runtime+runtime+runtime+runtime+runtime
# 15625 opening_weekend_gross ~ runtime+runtime+runtime+runtime+runtime+runtime
#       k adj.r.squared AIC      AICc     BIC
# 1     1 0.08805418    1766.738 1766.744 1780.132
# 2     2 0.09007686    1766.308 1766.327 1784.167
# 3     2 0.08915001    1766.962 1766.981 1784.820
# 4     2 0.50929508    1369.862 1369.881 1387.721
# 5     2 0.17041612    1706.965 1706.983 1724.823
# 6     2 0.09007686    1766.308 1766.327 1784.167
# 7     2 0.09007686    1766.308 1766.327 1784.167
# 8     3 0.09076594    1766.817 1766.854 1789.139
# 9     3 0.50872206    1371.606 1371.644 1393.929
# 10    3 0.17104204    1707.474 1707.512 1729.797
# 11    2 0.08915001    1766.962 1766.981 1784.820
# 12    3 0.09076594    1766.817 1766.854 1789.139
# 13    2 0.08915001    1766.962 1766.981 1784.820
# 14    3 0.51296980    1366.031 1366.069 1388.354
# 15    3 0.17298219    1705.970 1706.008 1728.293
# 16    2 0.50929508    1369.862 1369.881 1387.721
# 17    3 0.50872206    1371.606 1371.644 1393.929
# 18    3 0.51296980    1366.031 1366.069 1388.354
# 19    2 0.50929508    1369.862 1369.881 1387.721
# 20    3 0.51066545    1369.061 1369.099 1391.384
# 21    2 0.17041612    1706.965 1706.983 1724.823
# 22    3 0.17104204    1707.474 1707.512 1729.797
# 23    3 0.17298219    1705.970 1706.008 1728.293
# 24    3 0.51066545    1369.061 1369.099 1391.384
# 25    2 0.17041612    1706.965 1706.983 1724.823
# 26    2 0.09007686    1766.308 1766.327 1784.167
# 27    2 0.09007686    1766.308 1766.327 1784.167
# 28    3 0.09076594    1766.817 1766.854 1789.139
# 29    3 0.50872206    1371.606 1371.644 1393.929
# 30    3 0.17104204    1707.474 1707.512 1729.797
# ⋮     ⋮ ⋮             ⋮        ⋮        ⋮
# 15596 3 0.5106655     1369.061 1369.099 1391.384
# 15597 3 0.4948966     1389.424 1389.461 1411.747
# 15598 3 0.4896793     1396.021 1396.059 1418.344
# 15599 2 0.4875124     1397.747 1397.765 1415.605
# 15600 2 0.4875124     1397.747 1397.765 1415.605
# 15601 2 0.1704161     1706.965 1706.983 1724.823
# 15602 3 0.1710420     1707.474 1707.512 1729.797
# 15603 3 0.1729822     1705.970 1706.008 1728.293
# 15604 3 0.5106655     1369.061 1369.099 1391.384
# 15605 2 0.1704161     1706.965 1706.983 1724.823
# 15606 3 0.1710420     1707.474 1707.512 1729.797
# 15607 2 0.1444194     1726.774 1726.793 1744.633
# 15608 3 0.1462183     1726.417 1726.455 1748.740
# 15609 3 0.4948966     1389.424 1389.461 1411.747
# 15610 2 0.1444194     1726.774 1726.793 1744.633
# 15611 3 0.1729822     1705.970 1706.008 1728.293
# 15612 3 0.1462183     1726.417 1726.455 1748.740
# 15613 2 0.1394749     1730.474 1730.492 1748.332
# 15614 3 0.4896793     1396.021 1396.059 1418.344
# 15615 2 0.1394749     1730.474 1730.492 1748.332
# 15616 3 0.5106655     1369.061 1369.099 1391.384
# 15617 3 0.4948966     1389.424 1389.461 1411.747
# 15618 3 0.4896793     1396.021 1396.059 1418.344
# 15619 2 0.4875124     1397.747 1397.765 1415.605
# 15620 2 0.4875124     1397.747 1397.765 1415.605
# 15621 2 0.1704161     1706.965 1706.983 1724.823
# 15622 2 0.1444194     1726.774 1726.793 1744.633
# 15623 2 0.1394749     1730.474 1730.492 1748.332
# 15624 2 0.4875124     1397.747 1397.765 1415.605
# 15625 1 0.1387143     1730.045 1730.051 1743.438

# %%
rbind(result[which.max(result$adj.r.squared),]
      ,result[which.min(result$AIC),]
      ,result[which.min(result$AICc),]
      ,result[which.min(result$BIC),]
)
# Out:
#   model
# 1 opening_weekend_gross ~ production_budget_in_millions+runtime+audience_rating+monthofrelease+audience_rating+audience_rating
# 2 opening_weekend_gross ~ production_budget_in_millions+runtime+monthofrelease+audience_rating+audience_rating+audience_rating
# 3 opening_weekend_gross ~ production_budget_in_millions+runtime+monthofrelease+audience_rating+audience_rating+audience_rating
# 4 opening_weekend_gross ~ production_budget_in_millions+audience_rating+audience_rating+audience_rating+audience_rating+audience_rating
#   k adj.r.squared AIC      AICc     BIC
# 1 4 0.5145656     1364.917 1364.980 1391.705
# 2 4 0.5145656     1364.917 1364.980 1391.705
# 3 4 0.5145656     1364.917 1364.980 1391.705
# 4 2 0.5092951     1369.862 1369.881 1387.721

# %%
fit <- lm(opening_weekend_gross ~ production_budget_in_millions+audience_rating, scaled)

# %%
summary(fit)
# Out:
# Call:
# lm(formula = opening_weekend_gross ~ production_budget_in_millions +
#     audience_rating, data = scaled)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.1437 -0.3189 -0.0822  0.1660  4.8152
#
# Coefficients:
#                                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)                   -2.285e-16  2.765e-02   0.000        1
# production_budget_in_millions  6.601e-01  2.814e-02  23.461  < 2e-16 ***
# audience_rating                1.794e-01  2.814e-02   6.376 3.48e-10 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.7005 on 639 degrees of freedom
# Multiple R-squared:  0.5108,	Adjusted R-squared:  0.5093
# F-statistic: 333.6 on 2 and 639 DF,  p-value: < 2.2e-16

# %%
plot(y=studres(fit),x=fit$fitted.values)
# Out:
# plot without title

# %%
plot(y=abs(studres(fit)),x= fit$fitted.values)
# Out:
# plot without title

# %%
rfit <- lm(abs(studres(fit)) ~ fit$fitted.values)

# %%
rfit$fitted.values %>% str()
# Out:
#  Named num [1:642] 1.812 1.607 1.715 0.737 1.27 ...
#  - attr(*, "names")= chr [1:642] "1" "2" "3" "4" ...

# %%
scaled %>% str()
# Out:
# 'data.frame':	642 obs. of  6 variables:
#  $ opening_weekend_gross        : num  3.54 3.77 4.23 1.78 4.11 ...
#  $ runtime                      : num  -0.204 0.179 1.202 1.138 2.8 ...
#  $ production_budget_in_millions: num  2.847 2.847 2.847 0.364 1.436 ...
#  $ critic_rating                : num  1.8513 0.0246 0.8619 -0.0515 1.0521 ...
#  $ audience_rating              : num  1.902 -0.177 0.924 0.129 1.596 ...
#  $ monthofrelease               : num  -0.176 -1.075 -0.476 -0.176 1.322 ...

# %%
wfit <- lm(opening_weekend_gross ~ production_budget_in_millions+audience_rating, scaled,weights=(1/(rfit$fitted.values^2)))

# %%
summary(wfit)
# Out:
# Call:
# lm(formula = opening_weekend_gross ~ production_budget_in_millions +
#     audience_rating, data = scaled, weights = (1/(rfit$fitted.values^2)))
#
# Weighted Residuals:
#     Min      1Q  Median      3Q     Max
# -7.0265 -0.6582 -0.2600  0.3581 22.0119
#
# Coefficients:
#                                Estimate Std. Error t value Pr(>|t|)
# (Intercept)                   -0.067641   0.037115  -1.823   0.0688 .
# production_budget_in_millions  0.511129   0.050391  10.143   <2e-16 ***
# audience_rating                0.006238   0.015682   0.398   0.6909
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.427 on 639 degrees of freedom
# Multiple R-squared:  0.1566,	Adjusted R-squared:  0.154
# F-statistic: 59.33 on 2 and 639 DF,  p-value: < 2.2e-16

# %%
plot(y=studres(wfit),x=wfit$fitted.values)
# Out:
# plot without title

# %%
AICc_from_AIC <- function(AIC,fit) {    
    n <- length(fit$residuals)  
    k <- length(fit$coefficients) - 1    
    correction <- (2*k^2 + 2*k) / (n - k - 1)
    return ( AIC + correction )
    }
    
result <- data_frame()
for (form in models) {
    #print(form)
    fit <- lm(data=scaled, formula = as.formula(form)) 
    rfit <- lm(abs(studres(fit)) ~ fit$fitted.values)
    wfit <- lm(data = scaled, as.formula(form), weights=(1/(rfit$fitted.values^2)))
    glance_of_fit <- glance(fit) %>%
                     mutate( model=form
                            ,k = length(fit$coefficients) - 1   
                            ,AICc = AICc_from_AIC(AIC,fit)) %>% 
                     dplyr::select(c( 'model' 
                                     ,'k'
                                     ,'adj.r.squared'
                                     ,'AIC'
                                     ,'AICc'
                                     ,'BIC')
                                  )
    result <- rbind(result,glance_of_fit)
}
